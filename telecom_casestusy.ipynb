# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\HP\\Documents\\week4'

# %%
df=pd.read_excel('C:\\Users\\HP\\Documents\\week4\\Telco-Customer-Churn.xlsx')
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            0.0     Yes         No     1.0           No
# 1  5575-GNVDE    Male            0.0      No         No    34.0          Yes
# 2  3668-QPYBK    Male            0.0      No         No     2.0          Yes
# 3  7795-CFOCW    Male            0.0      No         No    45.0           No
# 4  9237-HQITU  Female            0.0      No         No     2.0          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
#check null values

# %%
df.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen       float64
# Partner              object
# Dependents           object
# tenure              float64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %% [markdown]
# # Compare churn count with respect to gender.

# %%
sns.countplot(x='Churn',hue='gender',data=df)
plt.title('Gender vs Churn count')
# Out:
# Text(0.5, 1.0, 'Gender vs Churn count')

# %% [markdown]
# # Find out how many female senior citizens there in the dataset

# %%
df1=df[df['SeniorCitizen']==1.0]

# %%
df1.SeniorCitizen.count()
# Out:
# 1142

# %%
df2=df1['gender']=='Female'

# %%
df2.value_counts()
# Out:
# False    574
# True     568
# Name: gender, dtype: int64

# %%
# There are 568 female senior citizens 0ut of 1142 in the data set

# %%
sns.countplot(data=df,x='SeniorCitizen',hue='gender')
plt.title('Seniorcitizen vs Gender')
# Out:
# Text(0.5, 1.0, 'Seniorcitizen vs Gender')

# %% [markdown]
# # Compare 'tenure' with 'Total Charges'

# %%
sns.scatterplot(data =df, x = 'tenure', y ='TotalCharges')
plt.title("Tenure vs Total Charges")
plt.tight_layout()

# %%
#Total charges is inversly propotional to tenure.The band of Total charge values is increasing with tenure.

# %% [markdown]
# # Find out which contract is preferred by the senior citizen.

# %%
sns.countplot(data=df,hue='SeniorCitizen',x='Contract')
plt.title("Contracts preferred by  Citizens")
plt.tight_layout()

# %%
s_df=df[df['SeniorCitizen']==1.0]
s_df
sns.countplot(x='Contract', data=s_df)
plt.title("Contract preferred by Senior citizen")
plt.tight_layout()

# %%
#most of the senior citizens preffering month-month contract than one year contract and two year contract

# %% [markdown]
# # Comment on your finds on Payment Method

# %%
#check the different method of payment

# %%
df['PaymentMethod'].value_counts()
# Out:
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: PaymentMethod, dtype: int64

# %%
sns.countplot(data=df,x='PaymentMethod')
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3]),
#  [Text(0, 0, 'Electronic check'),
#   Text(1, 0, 'Mailed check'),
#   Text(2, 0, 'Bank transfer (automatic)'),
#   Text(3, 0, 'Credit card (automatic)')])

# %%
sns.countplot(x ='PaymentMethod', hue='InternetService', data=df)
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3]),
#  [Text(0, 0, 'Electronic check'),
#   Text(1, 0, 'Mailed check'),
#   Text(2, 0, 'Bank transfer (automatic)'),
#   Text(3, 0, 'Credit card (automatic)')])

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
df=pd.read_excel('C:\\Users\\HP\\Documents\\week4\\Telco-Customer-Churn.xlsx')
plt.figure(figsize = (14,5))

plt.subplot(1,3,1)
sns.histplot(y= 'PaymentMethod', data =df, hue = 'gender')
plt.ylabel("")
plt.title("Payment methods across gender")

plt.subplot(1,3,2)
sns.histplot(y= 'PaymentMethod', data =df, hue = 'SeniorCitizen')
plt.title("Payment methods across Citizen ")
plt.ylabel("")

plt.subplot(1,3,3)
sns.histplot(y = 'PaymentMethod', data = df, hue ='Churn')
plt.title("Payment methods & Churn")
plt.ylabel("")
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# Text(0, 0.5, '')

# %%
# more no.of.people usingelectronic payment method, it does not vary depend on each features.but the fiber optic internet service showing the largest quantity of electronic payment method
